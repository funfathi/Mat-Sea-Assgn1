# %%
import pandas
import pandas as pd

# %%
sl=pd.read_csv('Salaries.csv')
sl
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# 2 Display top 10 rows of the dataset
sl.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
sl.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
# 3 Find shapeof our dataset (number opf rows and number of coloumns)
sl.shape
# Out:
# (148654, 13)

# %%
# 4getting information about the dataseT LIKE TOTAL NUMber of rows and number of coloumns ,datasets of each coloumns and menory requiremne
sl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
# 5  check null values in dataset
sl.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True         True      True
# 148651  False         False     False     True         True      True
# 148652  False         False     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
#q=Q-6 drop ID,notes , agency and status columns
sl.drop(columns=['Id','Notes','Agency','Status'],inplace=True)
sl
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
#Q-7 get overall statistics about the dataset
sl.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448841    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
#Q_8 find occurence of employee names(top 5)
sl.EmployeeName.value_counts().head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
#Q_9 find the number of unique job titles
sl['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
#Q_10 Total number of job title contains
sl[sl['JobTitle']=='CAPTAIN III (POLICE DEPARTMENT)'].count()
# Out:
# EmployeeName        37
# JobTitle            37
# BasePay             37
# OvertimePay         37
# OtherPay            37
# Benefits             0
# TotalPay            37
# TotalPayBenefits    37
# Year                37
# dtype: int64

# %%
#Q_11 Display all the employee names from Fire Department
#DISPLAY ALL EMPLOYEE NAMES  FROM FIRE DEPARTMENT
sl[sl['JobTitle']=='BATTALION CHIEF, (FIRE DEPARTMENT)']['EmployeeName']
# Out:
# 6                 ALSON LEE
# 8            MICHAEL MORRIS
# 14           DAVID FRANKLIN
# 18               MARTY ROSS
# 23            VICTOR WYRSCH
# 27           RAYMOND GUZMAN
# 34                JOSE VELO
# 39             BRENDAN WARD
# 40         MICHAEL THOMPSON
# 41            THOMAS ABBOTT
# 46         BRYAN RUBENSTEIN
# 50          KIRK RICHARDSON
# 63            CHARLES CRANE
# 71       RICHARD BUSALACCHI
# 76              KEVIN BURKE
# 79         EDUARDO GONZALEZ
# 82             LORRIE KALOS
# 86           MICHAEL BRYANT
# 90            MARK GONZALES
# 94                 REX HALE
# 97              KEVIN SMITH
# 100            KEVIN TAYLOR
# 106              SAMSON LAI
# 118             KHAIRUL ALI
# 127             JOHN HICKEY
# 134        ZACHARY PUMPHREY
# 151         MICHAEL KEARNEY
# 152      MATTHEW MCNAUGHTON
# 184           DENNIS SUTTER
# 209          ROBERT SERRANO
# 210         JAMES VANNUCCHI
# 312             JAMES BLAKE
# 327        RUDY CASTELLANOS
# ...

# %%
#Q_12 FIND MINIMUM ,MAXIMUM,AVERAGE BASEPAY
sl['BasePay'].agg(['min','max','mean'])
# Out:
# min       -166.010000
# max     319275.010000
# mean     66325.448841
# Name: BasePay, dtype: float64

# %%
#Q_13 REPLACE'NOT PROVIDED' IN EMPLOYEENAME  COLOUMN TO NAN
sl.replace({'EmployeeName':{'Not provided':'NaN'}})
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
#Q_14 DROP THE ROWS HAVING 5 MISSING VALUES
sl.replace({'Not provided':'NaN'})
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                             NaN
# 148651                NaN                                             NaN
# 148652                NaN                                             NaN
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
sl.dropna(thresh=len(sl.columns))
# Out:
#               EmployeeName                      JobTitle    BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160         Gregory Suhr               Chief of Police  302578.00
# 36161           Khoa Trinh   Electronic Maintenance Tech  111921.00
# 36162   Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...                    ...                           ...        ...
# 148645    Carolyn A Wilson     Human Services Technician       0.00
# 148647      Joann Anderson   Communications Dispatcher 2       0.00
# 148648         Leon Walker                     Custodian       0.00
# 148649       Roy I Tillery                     Custodian       0.00
# 148653           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 36159     220909.48  13126.31  44430.12  362844.66         407274.78  2012
# ...

# %%
#Q_15 FIND THE JOB TITLE OF ALBERT PARDON  
sl[sl['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
#Q_16 HOW MUCHNALBERT PARDON MAKE (INCLUDE BENEFITS)
sl[sl['EmployeeName']=='ALBERT PARDINI']['Benefits']
# Out:
# 2   NaN
# Name: Benefits, dtype: float64

# %%
#Q_17 DISPLAY NAMES  OF THE PERSON HAVING THE HIGHEST BASEPAY
sl[sl['BasePay']==319275.01000]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
#Q_18  find average basepay of all employees per year
sl.BasePay.mean()
# Out:
# 66325.44884050643

# %%
#Q_19  find average basepay of all employees per job title
sl.groupby(['JobTitle','EmployeeName'])['BasePay'].agg('mean')
# Out:
# JobTitle            EmployeeName
# ACCOUNT CLERK       ALICE BRONSON      43417.74
#                     ALISHA WILLIS      11247.02
#                     AMADO LUMAS JR     49777.81
#                     ANA VILAR UY       49741.42
#                     ANNA BOYD          49688.80
#                                          ...
# Youth Comm Advisor  Mario R Yedidia    13915.80
#                     Mario Yedidia      57544.73
#                     Phimy  Truong      52433.88
#                     Phimy Truong       32417.42
# ZOO CURATOR         MYRON SULAK        43148.00
# Name: BasePay, Length: 119698, dtype: float64

# %%
#Q_20 find average basepay of employee having job title ACCOUNTANT
sl[sl['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %%
#Q_21  Find top 5 most common jobs
sl.JobTitle.value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
